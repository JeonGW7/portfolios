# %% [markdown]
# # Crawling - BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
with open('00.Example.html') as file:
  soup=BeautifulSoup(file,'html.parser')

soup

# %% [markdown]
# * find() : 해당조건에 맞는 하나의 태그를 가져옴 / 중복시에는 첫번째 것만 가져옴

# %%
soup.find('p')
# Out:
# <p>a</p>

# %%
soup.find('div')
# Out:
# <div>
# <p>a</p><p>b</p><p>c</p>
# </div>

# %%
soup.find('ul')
# Out:
# <ul>
# <li>삼겹살</li>
# <li>치킨</li>
# <li>비빕밥</li>
# </ul>

# %% [markdown]
# * find_all() 조건에 맞는 모든 태그를 리스트형태로 반환

# %%
lis = soup.find_all('li')

# %%
lis
# Out:
# [<li>삼겹살</li>, <li>치킨</li>, <li>비빕밥</li>]

# %%
all_ps=soup.find_all('p')

# %%
all_ps
# Out:
# [<p>a</p>,
#  <p>b</p>,
#  <p>c</p>,
#  <p>X</p>,
#  <p>Y</p>,
#  <p>Z</p>,
#  <p>1</p>,
#  <p>2</p>,
#  <p>3</p>,
#  <p>This is a paragraph.</p>]

# %%
len(all_ps)
# Out:
# 10

# %%
divs=soup.find_all('div')
divs
# Out:
# [<div>
#  <p>a</p><p>b</p><p>c</p>
#  </div>, <div class="ex_class sample">
#  <p>X</p><p>Y</p><p>Z</p>
#  </div>, <div id="ex_id">
#  <p>1</p><p>2</p><p>3</p>
#  </div>]

# %%
divs[1].find_all('p')
# Out:
# [<p>X</p>, <p>Y</p>, <p>Z</p>]

# %% [markdown]
# * select_one() : CSS selector 로 하나의 노드만 찾는 메소드

# %%
#tag이름
soup.select_one('div')
# Out:
# <div>
# <p>a</p><p>b</p><p>c</p>
# </div>

# %%
#class 이름 : 클래스 이름 앞에 . 을 붙임
#soup.select_one('a.a')
soup.select_one('.a')
# Out:
# <a class="a sample" href="www.naver.com">네이버</a>

# %%
#id 이름 : id 이름 앞에 #을 붙임
#soup.select_one('div#ex_id')
soup.select_one('div#ex_id')
# Out:
# <div id="ex_id">
# <p>1</p><p>2</p><p>3</p>
# </div>

# %%
#여러개의 클래스 이름
soup.select_one('.ex_class.sample')  # 공백대신 . 사용
# Out:
# <div class="ex_class sample">
# <p>X</p><p>Y</p><p>Z</p>
# </div>

# %% [markdown]
# * select() : CSS selector로 모든 노드를 찾아 리스트로 반환

# %%
soup.select('.sample')
# Out:
# [<div class="ex_class sample">
#  <p>X</p><p>Y</p><p>Z</p>
#  </div>, <a class="a sample" href="www.naver.com">네이버</a>]

# %%
soup.select("#ex_id")
# Out:
# [<div id="ex_id">
#  <p>1</p><p>2</p><p>3</p>
#  </div>]

# %% [markdown]
# * 결과값 가져오기

# %%
atag=soup.find('a')
atag.get_text(), atag.string
# Out:
# ('네이버', '네이버')

# %%
#속성값 가져오기
atag['href']
# Out:
# 'www.naver.com'

# %%
lis = soup.find('ul').find_all('li')
lis
# Out:
# [<li>삼겹살</li>, <li>치킨</li>, <li>비빕밥</li>]

# %%
for li in lis:
  print(li.get_text())
# Out:
# 삼겹살
# 치킨
# 비빕밥

# %%
menu=[]
for li in lis:
  menu.append(li.get_text())
menu
# Out:
# ['삼겹살', '치킨', '비빕밥']

# %%
trs=soup.find('table').find_all('tr')
for tr in trs:
  tds=tr.find_all('td')
  for td in tds:
    print(td.get_text(),end=' ')
  print()
# Out:
# A B C
# x y z

# %%
trs
# Out:
# [<tr>
#  <td>A</td>
#  <td>B</td>
#  <td>C</td>
#  </tr>, <tr>
#  <td>x</td>
#  <td>y</td>
#  <td>z</td>
#  </tr>]
