# %% [markdown]
# 1강

# %%
var1="Hello"
print(var1)
print(id(var1))
print(type(var1))
# Out:
# Hello
# 140261061113776
# <class 'str'>

# %%
var2=100
print(var2)
print(id(var2))
print(type(var2))
# Out:
# 100
# 94342881154656
# <class 'int'>

# %%
var3=150.23
print(var3)
print(id(var3))
print(type(var3))
# Out:
# 150.23
# 140261029221136
# <class 'float'>

# %%
var4=True
print(var4)
print(id(var4))
print(type(var4))
# Out:
# True
# 94342880477440
# <class 'bool'>

# %%
import keyword
python_keyword=keyword.kwlist
print(python_keyword)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=1
b='1'
a
# Out:
# 1

# %%
b
# Out:
# '1'

# %%
a=int(10.5)
print(type(a))
# Out:
# <class 'int'>

# %%
a
# Out:
# 10

# %%
b=float(10)
print(type(b))
# Out:
# <class 'float'>

# %%
b
# Out:
# 10.0

# %%
print(int(True))
print(int(False))
# Out:
# 1
# 0

# %%
num1=100
num2=20

# %%
add=num1+num2
print('add=',add)
# Out:
# add= 120

# %%
sub=num1-num2
print('sub=',sub)
# Out:
# sub= 80

# %%
mul=num1*num2
print('mul=',mul)
# Out:
# mul= 2000

# %%
div=num1/num2
print('div=',div)
# Out:
# div= 5.0

# %%
div2=num1%num2
print('div2=',div2)
# Out:
# div2= 0

# %%
square=num1**2
square
# Out:
# 10000

# %%
bool_result= num1!=num2
print(bool_result)
# Out:
# True

# %%
bool_result= num1==num2
print(bool_result)
# Out:
# False

# %%
bool_result= num1>num2
print(bool_result)
# Out:
# True

# %%
bool_result= num1>=num2
print(bool_result)
# Out:
# True

# %%
bool_result= num1<num2
print(bool_result)
# Out:
# False

# %%
bool_result= num1<=num2
print(bool_result)
# Out:
# False

# %%
log_result=num1>=50 and num2 <=10
print(log_result)
# Out:
# False

# %%
log_result=num1>=50 or num2 <=10
print(log_result)
# Out:
# True

# %%
log_result=num1>=50
print(log_result)
# Out:
# True

# %%
log_result=not(num1>=50)
print(log_result)
# Out:
# False

# %%
i=tot=10
i,tot
# Out:
# (10, 10)

# %%
i+=1
tot+=1
print(i,tot)
# Out:
# 16 15

# %%
print('출력1',end=',')
print('출력2')
# Out:
# 출력1,출력2

# %%
v1,v2=100,200
print(v1,v2)
# Out:
# 100 200

# %%
v2,v1=v1,v2
print(v1,v2)
# Out:
# 200 100

# %%
lst=[1, 2, 3, 4, 5]
v1,*v2=lst
print(v1,v2)
# Out:
# 1 [2, 3, 4, 5]

# %% [markdown]
# ##2.3.1 표준입력장치

# %%
num=int(input("숫자입력:"))
# Out:
# 숫자입력:2

# %%
print('num_type:',type(num))
# Out:
# num_type: <class 'int'>

# %%
print('num=',num*2)
# Out:
# num= 4

# %% [markdown]
# ##2.3.2 표준출력장치

# %%
print('value= ',10+20+30+40)
# Out:
# value=  100

# %%
print("010","1234","5678",sep="-")
# Out:
# 010-1234-5678

# %%
print('value',10,end=',')
print('value=20',20)
# Out:
# value 10,value=20 20

# %%
print("원주율=",format(3.14159265452479,'.3f'))
# Out:
# 원주율= 3.142

# %%
print(f'원주율={3.1415926443:.2f}')
# Out:
# 원주율=3.14

# %%
print("금액=",format(10000,'10d'))
# Out:
# 금액=      10000

# %%
print(f'금액={10000:^10}')
# Out:
# 금액=  10000

# %%
print("금액=",format(10000,'3,d'))
# Out:
# 금액= 10,000

# %%
name="홍길동"
age=35
price=125.456
print("이름:%s,나이:%d,,data=%.2f"%(name,age,price))
# Out:
# 이름:홍길동,나이:35,,data=125.46

# %%
print("이름:{},나이:{},data:{}".format(name,age,price))
# Out:
# 이름:홍길동,나이:35,data:125.456

# %%
print(f"이름:{name},나이:{age},data:{price}")
# Out:
# 이름:홍길동,나이:35,data:125.456

# %%
"hello world"
# Out:
# 'hello world'

# %%
'python is fun'
# Out:
# 'python is fun'

# %%
"""life is too short"""
# Out:
# 'life is too short'

# %%
food="python's favorite food is perl"
food
# Out:
# "python's favorite food is perl"

# %%
food2='python\'s favorite food is perl'
food2
# Out:
# "python's favorite food is perl"

# %%
say="\"python is very easy.\" he says"
say
# Out:
# '"python is very easy." he says'

# %%
multiline1 = 'life is too short \n you need python'
multiline1
# Out:
# 'life is too short \n you need python'

# %%
multiline='''
여러줄의
문장들을
한번에 넣을수 있음
'''
multiline
# Out:
# '\n여러줄의\n문장들을\n한번에 넣을수 있음\n'

# %%
head='python'
tail=' is fun!'
head+tail
# Out:
# 'python is fun!'

# %%
head*2
# Out:
# 'pythonpython'

# %%
head+head
# Out:
# 'pythonpython'

# %%
a="Life is too short, you need python"
a[0]
# Out:
# 'L'

# %%
a[12]
# Out:
# 's'

# %%
a[-1]
# Out:
# 'n'

# %%
a[0:4]
# Out:
# 'Life'

# %%
a="20220418Rainy"
date=a[:8]
weather=a[8:]
date, weather
# Out:
# ('20220418', 'Rainy')

# %%
# a[처음숫자:끝:간격]

# %%
"i eat %d apple"%3
# Out:
# 'i eat 3 apple'

# %%
number=10
day="three"
"i eat %d apples so i was sick for %s days"%(number,day)
# Out:
# 'i eat 10 apples so i was sick for three days'

# %%
"%10s"%"hi"
# Out:
# '        hi'

# %%
"%0.4f"%3.13213123123
# Out:
# '3.1321'

# %%
a='hobby'
a.count('b')
# Out:
# 2

# %%
a="python is best program"
a.find('b')
# Out:
# 10

# %%
a.find('k')
# Out:
# -1

# %%
a="python is best program"
a.index('t')
# Out:
# 2

# %%
a=','
a.join('abcd')
# Out:
# 'a,b,c,d'

# %%
a='hi'
a.upper()
# Out:
# 'HI'

# %%
a.lower()
# Out:
# 'hi'

# %%
a='                hi    '
a.strip()
# Out:
# 'hi'

# %%
a="java is best program"
a.replace("java","python")
# Out:
# 'python is best program'

# %%
a="java is best program"
a.split()
# Out:
# ['java', 'is', 'best', 'program']

# %%
a.strip()
# Out:
# 'java is best program'

# %%
print('adlflana\nnsdfsdf')
# Out:
# adlflana
# nsdfsdf

# %%
multiline1="life is thoo short\n you need python"
print(multiline1)
# Out:
# life is thoo short
#  you need python

# %% [markdown]
# ##조건문

# %%
money=True
if money:
  print("저금해라")
else:
  print("대출을 받아라")
# Out:
# 저금해라

# %%
x=5
y=3
x>y
# Out:
# True

# %%
money=3000
if money>=10000:
  print('저금해라')
else:print('대출받아라')
# Out:
# 대출받아라

# %%
money=2000
bitcoin=1
if money>=3000 or bitcoin:
  print('저금해라')
else:
  print("대출받아라")
# Out:
# 저금해라

# %%
print(1 in [1,2,3])
print(1 not in [1,2,3])
# Out:
# True
# False

# %%
pocket=['paper','cellphone','money']
if 'money' in pocket:
  print('저금')
else:
  print('대출')
# Out:
# 저금

# %%
if 'money' in pocket:
  pass
else:
  print('대출')

# %%
pocket=['paper','cellphone']
bitcoint=True
if 'money' in pocket:
  print('저금')
elif bitcoin:
  print('저금')
else:
  print('대출')
# Out:
# 저금

# %% [markdown]
# ##파이썬 print() 문제

# %%
print('신씨가 소리질렀다."도둑이야."')
# Out:
# 신씨가 소리질렀다."도둑이야."

# %%
print('"C:\Windows"')
# Out:
# "C:\Windows"

# %%
print('naver','kakao','sk','samsung',sep='/')
# Out:
# naver/kakao/sk/samsung

# %%
import random
station=['신도림','사당','신촌']
door=['왼쪽','오른쪽']
for i in station:
  print('이번역은 %s역입니다.내리실문은 %s입니다'%(i,random.choice(door)))
# Out:
# 이번역은 신도림역입니다.내리실문은 오른쪽입니다
# 이번역은 사당역입니다.내리실문은 오른쪽입니다
# 이번역은 신촌역입니다.내리실문은 왼쪽입니다

# %% [markdown]
# #파이썬 변수 문제

# %%
시가총액=298000000000000
현재가=50000
PER=15.79
print(시가총액,type(시가총액))
print(현재가,type(현재가))
print(PER,type(PER))
# Out:
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
num_str="720"
num_int=int(num)
print(num_int,type(num_int))
# Out:
# 720 <class 'int'>

# %%
aircon=48584
print('에어컨 가격:%d'%(aircon*36))
# Out:
# 에어컨 가격:1749024

# %% [markdown]
# #문자열 인덱싱 문제

# %%
letters='python'
print(letters[0],letters[2])
# Out:
# p t

# %%
string_index="홀짝홀짝홀짝"
print(string_index[::2])
# Out:
# 홀홀홀

# %% [markdown]
# #IF 문제

# %%
number1=15
if number1%3==0:
  print('%d는 3의 배수입니다'%number1)
else:
  print('%d는 3의 배수가 아닙니다'%number1)
# Out:
# 15는 3의 배수입니다

# %%
number2=16
if number2%3==0:
  print('%d는 3의 배수입니다'%number2)
else:
  print('%d는 3의 배수가 아닙니다'%number2)
# Out:
# 16는 3의 배수가 아닙니다

# %%
from datetime import datetime
hour=datetime.now().hour
print(hour)
if hour%8==0:
  print("종이 울립니다")
# Out:
# 8
# 종이 울립니다

# %% [markdown]
# #제2장 연습문제

# %%
su=5
dan=800
print(id(su))
print(id(dan))
print('금액={}'.format(su*dan))
# Out:
# 94342881151616
# 140260846350224
# 금액=4000

# %%
x=2
y=2.5*x**2+3.3*2+6
print(y)
# Out:
# 22.6

# %%
지방=int(input("지방의 그램을 입력하세요:"))
탄수화물=int(input("탄수화물의 그램을 입력하세요:"))
단백질=int(input("단백질의 그램을 입력하세요:"))
print("총칼로리:{}cal".format(지방*9+탄수화물*4+단백질*4))
# Out:
# 지방의 그램을 입력하세요:25
# 탄수화물의 그램을 입력하세요:520
# 단백질의 그램을 입력하세요:45
# 총칼로리:2485cal

# %%
word1=input("첫번째 단어:")
word2=input("두번째 단어:")
word3=input("세번째 단어:")
print("===================")
print(f"약자:{word1[0]}{word2[0]}{word3[0]}")
# Out:
# 첫번째 단어:Korea
# 두번째 단어:Baseball
# 세번째 단어:Orag
# ...
# 약자:KBO
