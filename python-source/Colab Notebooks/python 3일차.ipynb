# %%
s1=set([1,2,3,4,5,6])
s2=set([4,5,6,7,8,9])
s1&s2
# Out:
# {4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {4, 5, 6}

# %%
s1|s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1-s2
# Out:
# {1, 2, 3}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s1=set([1,2,3])
s1.add(4)
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.update([4,5,6])
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.remove(2)
s1
# Out:
# {1, 3, 4, 5, 6}

# %%
fruits = {'strawberry', 'grape', 'orange', 'pineapple', 'cherry'}
fruits
# Out:
# {'cherry', 'grape', 'orange', 'pineapple', 'strawberry'}

# %%
type(fruits)
# Out:
# set

# %% [markdown]
# set은 순서가 없어 인덱싱이 불가능하다

# %%
'peach' not in fruits
# Out:
# True

# %%
'orange' in fruits
# Out:
# True

# %%
set('안녕하세요')
# Out:
# {'녕', '세', '안', '요', '하'}

# %%
a={3,1,0,2}
a.pop()
# Out:
# 0

# %%
len(a)
# Out:
# 3

# %%
for i in a:
  print(a)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# {1, 2, 3}

# %%
s={1,3,5,3,1}
print(len(s))
print(s)
# Out:
# 3
# {1, 3, 5}

# %%
for d in s:
  print(d,end=' ')
# Out:
# 1 3 5

# %%
s2={3,6}
print(s.union(s2)) #합집합
print(s.difference(s2)) #차집합
print(s.intersection(s2)) #교집합
# Out:
# {1, 3, 5, 6}
# {1, 5}
# {3}

# %%
s3={1,3,5}
print(s3)
# Out:
# {1, 3, 5}

# %%
s3.add(7)
print(s3)
# Out:
# {1, 3, 5, 7}

# %%
s3.discard(3)
print(s3)
# Out:
# {1, 5, 7}

# %%
gender=['남','남','여','여']
#중복 제거
sgender=set(gender)
lgender=list(sgender)
print(lgender)
print(lgender[1])
# Out:
# ['남', '여']
# 여

# %% [markdown]
# #dictionary

# %%
dic={}
dic['dictionary']='1.A reference book...'
dic['python']='Any of various...  '
dic
# Out:
# {'dictionary': '1.A reference book...', 'python': 'Any of various...  '}

# %%
dic['dictionary']
# Out:
# '1.A reference book...'

# %%
smalldic={'dictionary':'reference','python':'snake'}
smalldic['python']
# Out:
# 'snake'

# %%
a={1:'a'}
a[2]='b'
a
# Out:
# {1: 'a', 2: 'b'}

# %%
del smalldic['dictionary']
smalldic
# Out:
# {'python': 'snake'}

# %%
a={1:'a',1:'b'}
a
# Out:
# {1: 'b'}

# %%
a={'name':'pey','phone':'01012345678','birth':'1231'}
a.keys()
# Out:
# dict_keys(['name', 'phone', 'birth'])

# %%
a.items()
# Out:
# dict_items([('name', 'pey'), ('phone', '01012345678'), ('birth', '1231')])

# %%
a.clear()
a
# Out:
# {}

# %%
a={'name':'pey','phone':'01012345678','birth':'1231'}
a.get('name')
# Out:
# 'pey'

# %%
a.get('phone')
# Out:
# '01012345678'

# %%
'name' in a
# Out:
# True

# %%
'email' in a
# Out:
# False

# %%
name=input('이름:')
age=int(input('나이:'))

privacy={'이름':'name','나이':'age'}
for key in privacy.keys():
  print('-키:',key)
for value in privacy.values():
  print('-갑:',value)

addr=input('주소:')
privacy['주소']=addr
print(privacy)
# Out:
# 이름:홍길동
# 나이:20
# -키: 이름
# -키: 나이
# -갑: name
# -갑: age
# 주소:서울
# {'이름': 'name', '나이': 'age', '주소': '서울'}

# %%
import requests
btc= requests.get("https://api.bithumb.com/public/ticker/").json()['data']
fl_range=int(btc['max_price'])-int(btc['min_price'])
if fl_range+int(btc['opening_price'])>int(btc['max_price']):
  print('상승장')
else:
  print('하락장')
# Out:
# 상승장

# %%
x={'a':10,'b':20,'c':30,'d':40}
x.setdefault('e')
x
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': None}

# %%
x.update(a=90)
x
# Out:
# {'a': 90, 'b': 20, 'c': 30, 'd': 40, 'e': None}

# %%
x['e']=300
x
# Out:
# {'a': 90, 'b': 20, 'c': 30, 'd': 40, 'e': 300}

# %%
x.update(a=900,f=60)
x
# Out:
# {'a': 900, 'b': 20, 'c': 30, 'd': 40, 'e': 300, 'f': 60}

# %%
x={'a':10,'b':20,'c':30,'d':40}
x.pop('a')
# Out:
# 10

# %%
x
# Out:
# {'b': 20, 'c': 30, 'd': 40}

# %%
x.pop('z',0)
# Out:
# 0

# %%
del x['c']
x
# Out:
# {'b': 20, 'd': 40}

# %%
x={'a':10,'b':20,'c':30,'d':40}
x.popitem()
# Out:
# ('d', 40)

# %%
x.get('a')
# Out:
# 10

# %%
for i in x:
  print(i)
# Out:
# a
# b
# c

# %%
for key in x.keys():
  print(key,x[key])
# Out:
# a 10
# b 20
# c 30

# %%
y={}
for k,v in x.items():

# %%
for k,v in x.items():
  print(k,v)
# Out:
# a 10
# b 20
# c 30

# %%
x={'a':10,'b':20,'c':30,'d':40}
x
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
y={}
for k,v in x.items():
  y[k]=v*v
y
# Out:
# {'a': 100, 'b': 400, 'c': 900, 'd': 1600}

# %%
y={key:value*value for key,value in x.items()}
y
# Out:
# {'a': 100, 'b': 400, 'c': 900, 'd': 1600}

# %%
y={key:value*value for key,value in x.items() if value%20==0}
y
# Out:
# {'b': 400, 'd': 1600}

# %%
x={'국어':[80,86,78,92],
   '영어':[70,82,94,90],
   '수학':[80,78,78,82]}

# %%
import pandas as pd
df = pd.DataFrame(x)
df
# Out:
#    국어  영어  수학
# 0  80  70  80
# 1  86  82  78
# 2  78  94  78
# 3  92  90  82

# %%
terrestrial_planet = {
    'Mercury': {
        'mean_radius': 2439.7,
        'mass': 3.3022E+23,
        'orbital_period': 87.969
    },
    'Venus': {
        'mean_radius': 6051.8,
        'mass': 4.8676E+24,
        'orbital_period': 224.70069,
    },
    'Earth': {
        'mean_radius': 6371.0,
        'mass': 5.97219E+24,
        'orbital_period': 365.25641,
    },
    'Mars': {
        'mean_radius': 3389.5,
        'mass': 6.4185E+23,
        'orbital_period': 686.9600,
    }
}
 
print(terrestrial_planet['Venus']['mean_radius'])    # 6051.8
# Out:
# 6051.8

# %%
dic=dict(key1=100,key2=200,key3=300)
dic
# Out:
# {'key1': 100, 'key2': 200, 'key3': 300}

# %%
person={'name':'홍길동','age':35,'address':'서울시'}
print(person)
print(person['name'])
print(type(dic),type(person))
# Out:
# {'name': '홍길동', 'age': 35, 'address': '서울시'}
# 홍길동
# <class 'dict'> <class 'dict'>

# %%
person['age']=45
print(person)
# Out:
# {'name': '홍길동', 'age': 45, 'address': '서울시'}

# %%
del person['address']
print(person)
# Out:
# {'name': '홍길동', 'age': 45}

# %%
person['pay']=350
print(person)
# Out:
# {'name': '홍길동', 'age': 45, 'pay': 350}

# %%
print(person['age'])
print('age' in person)
# Out:
# 45
# True

# %%
for key in person.keys():
  print(key)
for v in person.values():
  print(v)
for i in person.items():
  print(i)
# Out:
# name
# age
# pay
# 홍길동
# 45
# 350
# ('name', '홍길동')
# ('age', 45)
# ('pay', 350)

# %%
charset=['abc','code','band','band','abc']
wc={}
for key in charset:
  wc[key]=wc.get(key,0)+1
print(wc)
# Out:
# {'abc': 2, 'code': 1, 'band': 2}

# %% [markdown]
# #함수

# %%
abs(3)
# Out:
# 3

# %%
abs(-1.2)
# Out:
# 1.2

# %%
all([1,2,3])
# Out:
# True

# %%
all([1,2,3,0])
# Out:
# False

# %%
any([1,2,3,0])
# Out:
# True

# %%
any([0,""])
# Out:
# False

# %%
dir([1,2,3])

# %%
divmod(7,3)
# Out:
# (2, 1)

# %%
divmod(1.3,0.2)
# Out:
# (6.0, 0.09999999999999998)

# %%
for i,name in enumerate(['body','foo','bar']):
  print(i,name)
# Out:
# 0 body
# 1 foo
# 2 bar

# %%
eval('1+2')
# Out:
# 3

# %%
eval("'hi'+'a'")
# Out:
# 'hia'

# %%
eval('divmod(4,3)')
# Out:
# (1, 1)

# %%
def positive(x):
  return x>0

# %%
a=list(filter(positive,[1,-3,2,0,-5,6]))
print(a)
# Out:
# [1, 2, 6]

# %%
a=list(filter(lambda x: x>0,[1,-3,2,0,-5,6]))
print(a)
# Out:
# [1, 2, 6]

# %%
id(a)
# Out:
# 140487843756464

# %%
b=a
id(b)
# Out:
# 140487843756464

# %%
a=input()
print(a)
# Out:
# hi
# hi

# %%
type(a)
# Out:
# str

# %%
a='python'
len(a)
# Out:
# 6

# %%
len([1,2,3,4,5])
# Out:
# 5

# %%
def two_times(x):
  return x*2

# %%
a=list(map(two_times,[1,2,3,4]))
a
# Out:
# [2, 4, 6, 8]

# %%
a=list(map(lambda x:x*2,[1,2,3,4]))
a
# Out:
# [2, 4, 6, 8]

# %%
max([1,2,3])
# Out:
# 3

# %%
min([1,2,3,])
# Out:
# 1

# %%
max('python')
# Out:
# 'y'

# %%
min('python')
# Out:
# 'h'

# %%
pow(2,4)
# Out:
# 16

# %%
pow(3,3)
# Out:
# 27

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
round(4.6) #반올림
# Out:
# 5

# %%
round(5.682,2)
# Out:
# 5.68

# %%
sorted([3,2,1]) #정렬
# Out:
# [1, 2, 3]

# %%
list(zip([1,2,3],[4,5,6])) #자료형을 묶어주는 역할
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
list(zip([1,2,3],[4,5,6],[7,8,9]))
# Out:
# [(1, 4, 7), (2, 5, 8), (3, 6, 9)]

# %%
list(zip("abc","def"))
# Out:
# [('a', 'd'), ('b', 'e'), ('c', 'f')]

# %%
import pickle #dictionary 형태를 저장하는
f=open("test.txt",'wb')
data={1:'python',2:'you need'}
pickle.dump(data,f)
f.close()

# %%
 # !cat test.txt
# Out:
# you needqu.

# %%
f=open("test.txt",'rb')
data=pickle.load(f)
print(data)
# Out:
# {1: 'python', 2: 'you need'}

# %%
import time
print(time.time())
# Out:
# 1650434789.676458

# %%
print(time.localtime(time.time()))
# Out:
# time.struct_time(tm_year=2022, tm_mon=4, tm_mday=20, tm_hour=6, tm_min=7, tm_sec=35, tm_wday=2, tm_yday=110, tm_isdst=0)

# %%
import time
for i in range(5):
  print(i)
  time.sleep(1) #1초간격
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import random
print(random.random()) #0~1사이의 랜덤숫자
# Out:
# 0.2602916872976324

# %%
print(random.randint(1,10)) #1~10사이
# Out:
# 10

# %%
data=[1,2,3,4,5]
random.shuffle(data) #데이터 섞기 
data
# Out:
# [1, 4, 5, 3, 2]

# %%
import random
lotto=sorted(random.sample(range(1,46),6))
print(lotto)
# Out:
# [2, 9, 24, 30, 34, 37]

# %%
import webbrowser
webbrowser.open("http://google.com")

# %%
def 인사말_만들기(이름):
  인사말='안녕하세요' + 이름 + '님'
  return 인사말

def 인사말_바로하기(이름):
  인사말='안녕하세요' + 이름 + '님'
  print(인사말)

# %%
인사말=인사말_만들기('준이')
print(인사말)
인사말_바로하기('준이동생')
# Out:
# 안녕하세요준이님
# 안녕하세요준이동생님

# %%
def sum1(a,b):
  result=a+b
  return result

# %%
a=sum1(3,4)
print(a)
# Out:
# 7

# %%
def say():
  return 'Hi'

# %%
a=say()
print(a)
# Out:
# Hi

# %%
def sum_2(a,b):
  print("%d, %d의 합은 %d입니다"%(a,b,a+b))

# %%
sum_2(3,4)
# Out:
# 3, 4의 합은 7입니다

# %%
def say():
  print('Hi')

# %%
say()
# Out:
# Hi

# %%
def sum_many(*args): 
    sum = 0
    for i in args:
      sum=sum+i
    return sum

# %%
def print_kwargs(**kwargs): 
    for k in kwargs.keys():
        if(k == "name"): 
            print("당신의 이름은 :" + k)

# %%
def sum_and_mul(a,b):
  return a+b, a*b

# %%
result=sum_and_mul(3,4)
result
# Out:
# (7, 12)

# %%
def say_myself(name, old, man=True): 
  print("나의 이름은 %s 입니다." % name)
  print("나이는 %d살입니다." % old) 
  if man:
    print("남자입니다.")
  else:
    print("여자입니다.")

# %%
say_myself("박응용", 27)
# Out:
# 나의 이름은 박응용 입니다.
# 나이는 27살입니다.
# 남자입니다.

# %%
say_myself("박응용", 27, False)
# Out:
# 나의 이름은 박응용 입니다.
# 나이는 27살입니다.
# 여자입니다.

# %%
a = 1
def vartest(a): 
  a = a +1
vartest(a) 
print(a)
# Out:
# 1

# %%
a = 1
def vartest(): 
  global a
  a = a+1
vartest() 
print(a)
# Out:
# 2

# %%
add = lambda a, b: a+b
result = add(3,4) 
print(result)
# Out:
# 7

# %%
def add(a,b): 
  return a+b

# %%
def plus_ten(x):
  return x+10
plus_ten(5)
# Out:
# 15

# %%
#람다함수로 변형
plus_ten2 = lambda x : x+10
plus_ten(5)
# Out:
# 15

# %%
(lambda x : x+10)(5)
# Out:
# 15

# %%
list(map(lambda x: int(x)+10, input().split()))
# Out:
# 10
# [20]

# %%
def plus_ten(x):
  return int(x)+10
list(map(plus_ten, input().split()))
# Out:
# 10
# [20]

# %%
def factorial(n):
  if n==1:
    return 1
  return n*factorial(n-1)

# %%
print(factorial(5))
# Out:
# 120
