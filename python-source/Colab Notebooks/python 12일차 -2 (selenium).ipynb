# %%
# !apt-get update > /dev/null 2>&1
# !pip install selenium > /dev/null 2>&1
# !apt install chromium-chromedriver > /dev/null 2>&1

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')   # 화면없이 실행
options.add_argument('--no-sandbox')
options.add_argument("--single-process")
options.add_argument("--disable-dev-shm-usage")
driver = webdriver.Chrome('chromedriver', options=options)

# %%
url = 'https://www.google.co.kr'
driver.get(url)

# %%
search_box = driver.find_element(by=By.NAME, value='q')
search_box.send_keys('ChromeDrive')
search_box.send_keys(Keys.ENTER)
time.sleep(2)

# %%
divs = driver.find_elements(by=By.CSS_SELECTOR, value='#search .g')
len(divs)
# Out:
# 12

# %%
len(divs)
# Out:
# 10

# %%
div = divs[0]
title = div.find_element(By.CSS_SELECTOR, '.LC20lb.MBeuO.DKV0Md').text
title
# Out:
# 'ChromeDriver - WebDriver for Chrome - Downloads'

# %%
content = div.find_element(By.CSS_SELECTOR,'.VwiC3b.yXK7lf.MUxGbd').text
content
# Out:
# 'ChromeDriver 102.0.5005.27 · Supports Chrome version 10 · For more details, please see the · ChromeDriver 101.0.4951.41 · Supports Chrome version 101 · For more ...'

# %%
lines = []
for div in divs:
    try: 
        title = div.find_element(By.CSS_SELECTOR, '.LC20lb.MBeuO.DKV0Md').text
        content = div.find_element(By.CSS_SELECTOR,'.VwiC3b.yXK7lf.MUxGbd').text
    except:
        continue

    lines.append([title, content])

# %%
import pandas as pd

# %%
df = pd.DataFrame(lines, columns=['제목','내용'])
df
# Out:
#                                                   제목  \
# 0    ChromeDriver - WebDriver for Chrome - Downloads
# 1  Getting started - ChromeDriver - WebDriver for...
# 2   ChromeDriver · SeleniumHQ/selenium Wiki - GitHub
# 3             Install browser drivers - Selenium.dev
# 4                                           Index of
# 5                                 chromedriver - npm
# 6                        Using Chromedriver - Appium
# 7  chrome/test/chromedriver - chromium/src - Git ...
#
#                                                   내용
# 0  ChromeDriver 102.0.5005.27 · Supports Chrome v...
# 1  ChromeDriver is a separate executable that Sel...
# 2  Dec 26, 2021 — A browser automation framework ...
# 3  Mar 3, 2022 — ChromeDriver was started success...
# 4  Name, Last modified, Size, ETag. [DIR], 2.0, -...
# 5  ChromeDriver for Selenium. Latest version: 101...
# 6  Appium supports automating Android web pages (...
# 7  ChromeDriver is a standalone server which comm...
