# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/법정동코드 전체자료.txt',sep='\t',encoding='EUC-kR')
df.head(2)
# Out:
#         법정동코드       법정동명 폐지여부
# 0  1100000000      서울특별시   존재
# 1  1111000000  서울특별시 종로구   존재

# %%
df.tail(2)
# Out:
#             법정동코드                  법정동명 폐지여부
# 46326  5013032025  제주특별자치도 서귀포시 표선면 세화리   존재
# 46327  5013032026  제주특별자치도 서귀포시 표선면 토산리   존재

# %%
len(df)
# Out:
# 46328

# %%
df.shape
# Out:
# (46328, 3)

# %%
df=df[df.폐지여부=='폐지']
len(df)
# Out:
# 25777

# %%
#폐지된 주소는 삭제되도록 필터링
df=df[df.폐지여부=='존재']
df.shape
# Out:
# (20551, 3)

# %% [markdown]
# * 인덱싱

# %%
df.head(3)
# Out:
#         법정동코드           법정동명 폐지여부
# 0  1100000000          서울특별시   존재
# 1  1111000000      서울특별시 종로구   존재
# 2  1111010100  서울특별시 종로구 청운동   존재

# %%
df.법정동명.str[:5].head(3)
# Out:
# 0    서울특별시
# 1    서울특별시
# 2    서울특별시
# Name: 법정동명, dtype: object

# %% [markdown]
# * find : 찾기
#
# 각 문자열의 하위 문자열을 검색하는 데 사용
#
# 문자열이 발견되면 해당 문자열의 가장 낮은 인덱스를 반환
#
# 문자열이 없으면 -1을 반환

# %%
df.법정동명.str.find('서울').head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: 법정동명, dtype: int64

# %% [markdown]
# * 분할 : split

# %%
#서울특별시 종로구 청운동
df.법정동명.str.split().head()
# Out:
# 0              [서울특별시]
# 1         [서울특별시, 종로구]
# 2    [서울특별시, 종로구, 청운동]
# 3    [서울특별시, 종로구, 신교동]
# 4    [서울특별시, 종로구, 궁정동]
# Name: 법정동명, dtype: object

# %% [markdown]
# * 포함 글자 인식 : contains

# %%
df.법정동명.str.contains('서울').head(3)
# Out:
# 0    True
# 1    True
# 2    True
# Name: 법정동명, dtype: bool

# %%
seocho=df.법정동명.str.contains('서초').head(3)
seocho
# Out:
# 0    False
# 1    False
# 2    False
# Name: 법정동명, dtype: bool

# %% [markdown]
# * 문자 대체 : replace

# %%
df.법정동명.str.replace(' ','_').head(3)
# Out:
# 0            서울특별시
# 1        서울특별시_종로구
# 2    서울특별시_종로구_청운동
# Name: 법정동명, dtype: object

# %%
seocho.법정동명 = seocho.법정동명.str.replace(" ",'##')
seocho.tail()

# %%
seocho.법정동명=seocho.법정동명.str.replace('[^가-힣]',' ')
seocho.tail(3)

# %%
filename='서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv'
cctv=pd.read_csv(filename,skiprows=1,encoding='EUC-KR')

# %%
cctv.head(2)
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1,715      815    NaN    NaN    195    150      0     261      85
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0

# %%
cctv['총계']=cctv['총계'].apply(lambda x: int(x.replace(',','')))
#cctv['총계'].str.replace(',','').astype(int).head(3)
cctv.head()
# Out:
#     구분     총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1715      815    NaN    NaN    195    150      0     261      85
# 2  중 구   2447       16    114     87     77    236    240     372     386
# 3  용산구   2611       34     71    234    125    221    298     351     125
# 4  성동구   3829      163    144    208    107    325    255     967     415
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0
# 2     155     361    403
# 3     307     617    228
# 4     490     472    283
